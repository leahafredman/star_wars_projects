# %%
#importing libraries
import pandas as pd
import dfply as ply
import seaborn as sns
import matplotlib.pyplot as ply
# %matplotlib inline

# %%
#setting display options for pandas
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
#importing the data 
df_char = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/characters.csv')
df_planet = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/planets.csv')
df_spec = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/species.csv')
df_ships = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/starships.csv')
df_vcl = pd.read_csv('/Users/ariafredman/Documents/data_science/data/star_wars_info_data/vehicles.csv')

# %%
#looking at the SW character data

#column names look like they don't require any cleaning
print("Character dataframe column names: \n"
      , df_char.columns)

#First 5 rows of the dataframe
print("\n\nFirst 5 rows of character dataframe: \n",
      df_char.head())

#Some descriptive stats of the numeric variables
#it looks like height is an integer and not a float
#I'll examine that further in a bit
print("\n\nDescriptive stats of Character dataframe numeric variables: \n",
      df_char.describe())

#checking the variables' data types
#mass is an object, but should definitly be int or float
print("\n\nCharacter dataframe data types: \n",
     df_char.dtypes)
# Out:
# Character dataframe column names:
#  Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'gender', 'homeworld', 'species'],
#       dtype='object')
#
#
# First 5 rows of character dataframe:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human
#
#
# Descriptive stats of Character dataframe numeric variables:
#             height
# count   81.000000
# ...

# %%
#looking at the SW planets data

#column names look like they don't require any cleaning
print("Character dataframe column names: \n"
      , df_planet.columns)

#First 5 rows of the dataframe
print("\n\nFirst 5 rows of character dataframe: \n",
      df_planet.head())

#Some descriptive stats of the numeric variables
#it looks like numeric variables should be kept as floats
#we could probably round them a bit though
print("\n\nDescriptive stats of Character dataframe numeric variables: \n",
      df_planet.describe())

#checking the variables' data types
print("\n\nCharacter dataframe data types: \n",
     df_planet.dtypes)
#I don't think I understand enough about SW to understand the gravity bit

#the planets are the same as in the character dataframe
#so in theory we can connect those two together and play if we want
# Out:
# Character dataframe column names:
#  Index(['name', 'rotation_period', 'orbital_period', 'diameter', 'climate',
#        'gravity', 'terrain', 'surface_water', 'population'],
#       dtype='object')
#
#
# First 5 rows of character dataframe:
#         name  rotation_period  orbital_period  diameter              climate  \
# 0  Alderaan             24.0           364.0   12500.0            temperate
# 1  Yavin IV             24.0          4818.0   10200.0  temperate, tropical
# 2      Hoth             23.0           549.0    7200.0               frozen
# 3   Dagobah             23.0           341.0    8900.0                murky
# 4    Bespin             12.0          5110.0  118000.0            temperate
#
#                                   gravity                             terrain  \
# 0                              1 standard               grasslands, mountains
# 1                              1 standard                 jungle, rainforests
# ...

# %%
#looking at the SW species data

#column names look like they don't require any cleaning
#I think I'll change average_height and average_lifespan tho to avg_height and avg_lifespan
print("Character dataframe column names: \n"
      , df_spec.columns)

#First 5 rows of the dataframe
print("\n\nFirst 5 rows of character dataframe: \n",
      df_spec.head())

#Some descriptive stats of the numeric variables
#it looks like average_hight can probably be an int
print("\n\nDescriptive stats of Character dataframe numeric variables: \n",
      df_spec.describe())

#checking the variables' data types
#average_lifespan is an object, but should definitly be int or float
print("\n\nCharacter dataframe data types: \n",
     df_spec.dtypes)


#we might be able to connect these data with the other using the color columns and homeworld
# Out:
# Character dataframe column names:
#  Index(['name', 'classification', 'designation', 'average_height',
#        'skin_colors', 'hair_colors', 'eye_colors', 'average_lifespan',
#        'language', 'homeworld'],
#       dtype='object')
#
#
# First 5 rows of character dataframe:
#               name classification designation  average_height  \
# 0            Hutt      gastropod    sentient           300.0
# 1  Yoda's species         mammal    sentient            66.0
# 2      Trandoshan        reptile    sentient           200.0
# 3    Mon Calamari      amphibian    sentient           160.0
# 4            Ewok         mammal    sentient           100.0
#
#                  skin_colors          hair_colors            eye_colors  \
# 0          green, brown, tan                  NaN           yellow, red
# 1              green, yellow         brown, white  brown, green, yellow
# 2               brown, green                 none        yellow, orange
# ...

# %% [markdown]
# ### So looking at the vehicles data below, I don't think there's a way to connect them to the data above without knowing who has what type of vehicle (which maybe I'll look into in the future, but not right now). So I think I'll connect the above three dataframes together, and then the bottom two

# %%
#looking at the SW spaceshipts data

#column names look like they don't require any cleaning
#I think I'll change max_atmosphering_speed to max_atmos_speed, 
#cost_in_credits to credits_cost, and starship_class to ship_class
print("Character dataframe column names: \n"
      , df_ships.columns)

#First 5 rows of the dataframe
print("\n\nFirst 5 rows of character dataframe: \n",
      df_ships.head())

#Some descriptive stats of the numeric variables
#it looks like average_hight can probably be an int
print("\n\nDescriptive stats of Character dataframe numeric variables: \n",
      df_ships.describe())

#checking the variables' data types
#average_lifespan is an object, but should definitly be int or float
print("\n\nCharacter dataframe data types: \n",
     df_ships.dtypes)


#we might be able to connect these data with the other using the color columns and homeworld
# Out:
# Character dataframe column names:
#  Index(['name', 'model', 'manufacturer', 'cost_in_credits', 'length',
#        'max_atmosphering_speed', 'crew', 'passengers', 'cargo_capacity',
#        'consumables', 'hyperdrive_rating', 'MGLT', 'starship_class'],
#       dtype='object')
#
#
# First 5 rows of character dataframe:
#                             name                            model  \
# 0                      Executor  Executor-class star dreadnought
# 1  Sentinel-class landing craft     Sentinel-class landing craft
# 2                    Death Star      DS-1 Orbital Battle Station
# 3             Millennium Falcon          YT-1300 light freighter
# 4                        Y-wing                       BTL Y-wing
#
#                                         manufacturer  cost_in_credits  length  \
# 0                 Kuat Drive Yards, Fondor Shipyards     1.143350e+09   19000
# 1            Sienar Fleet Systems, Cyngus Spaceworks     2.400000e+05      38
# ...

# %%
#looking at the SW spaceshipts data

#column names look like they don't require any cleaning
#I think I'll change max_atmosphering_speed to max_atmos_speed, 
#cost_in_credits to credits_cost, and starship_class to ship_class
print("Character dataframe column names: \n"
      , df_vcl.columns)

#First 5 rows of the dataframe
print("\n\nFirst 5 rows of character dataframe: \n",
      df_vcl.head())

#Some descriptive stats of the numeric variables
#it looks like average_hight can probably be an int
print("\n\nDescriptive stats of Character dataframe numeric variables: \n",
      df_vcl.describe())

#checking the variables' data types
#average_lifespan is an object, but should definitly be int or float
print("\n\nCharacter dataframe data types: \n",
     df_vcl.dtypes)


#we might be able to connect these data with the other using the color columns and homeworld
# Out:
# Character dataframe column names:
#  Index(['name', 'model', 'manufacturer', 'cost_in_credits', 'length',
#        'max_atmosphering_speed', 'crew', 'passengers', 'cargo_capacity',
#        'consumables', 'vehicle_class'],
#       dtype='object')
#
#
# First 5 rows of character dataframe:
#                   name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer  cost_in_credits  length  \
# 0  Corellia Mining Corporation         150000.0    36.8
# 1            Incom Corporation          14500.0    10.4
# 2         SoroSuub Corporation          10550.0     3.4
# 3         Sienar Fleet Systems              NaN     6.4
# 4            Incom corporation              NaN     4.5
#
# ...
